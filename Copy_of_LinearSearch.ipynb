# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithra23125/algorithm/blob/main/Copy_of_LinearSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1


sizes = [1000, 5000, 10000, 50000, 100000, 200000]
times = []

def measure_time(n):
    arr = random.sample(range(n * 2), n)
    target = random.choice(arr)

    start_time = time.time()
    linear_search(arr, target)
    end_time = time.time()

    return end_time - start_time


for n in sizes:
    t = measure_time(n)
    times.append(t)
    print(f"n = {n}, Time Taken = {t:.6f} seconds")


plt.plot(sizes, times, marker='o', linestyle='-', color='b', label='Linear Search Time')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time Taken (seconds)')
plt.title('Linear Search Time Complexity')
plt.legend()
plt.grid()
plt.show()
# Out:
# n = 1000, Time Taken = 0.000020 seconds
# n = 5000, Time Taken = 0.000145 seconds
# n = 10000, Time Taken = 0.000031 seconds
# n = 50000, Time Taken = 0.001850 seconds
# n = 100000, Time Taken = 0.008785 seconds
# n = 200000, Time Taken = 0.012712 seconds
