# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithra23125/algorithm/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import time
import random

def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1
sizes = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
times = []

for size in sizes:
    arr = list(range(size))
    target = random.choice(arr)

    start_time = time.time()
    linear_search(arr, target)
    end_time = time.time()

    times.append(end_time - start_time)
plt.plot(sizes, times, marker='o')
plt.title('Linear Search Time Complexity')
plt.xlabel('List Size')
plt.ylabel('Time (seconds)')
plt.grid(True)
plt.show()

# %%
import time
import matplotlib.pyplot as plt

def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1
def measure_time_complexity():
    sizes = [100, 500, 1000, 5000, 10000, 50000, 100000]
    times = []

    for size in sizes:
        arr = list(range(size))
        target = size - 1  # Worst case scenario
        start_time = time.time()
        linear_search(arr, target)
        end_time = time.time()
        times.append(end_time - start_time)

    return sizes, times
def plot_time_complexity(sizes, times):
    plt.figure(figsize=(10, 6))
    plt.plot(sizes, times, marker='o', linestyle='-', color='b')
    plt.title('Linear Search Time Complexity')
    plt.xlabel('Input Size')
    plt.ylabel('Time (seconds)')
    plt.grid(True)
    plt.show()
sizes, times = measure_time_complexity()
plot_time_complexity(sizes, times)

# %%
import matplotlib.pyplot as plt
import time
import random

def binary_search(arr, x):
    low = 0
    high = len(arr) - 1
    mid = 0

    while low <= high:
        mid = (high + low) // 2

        if arr[mid] < x:
            low = mid + 1

        elif arr[mid] > x:
            high = mid - 1

        else:
            return mid


    return -1


sizes = [10, 100, 1000, 10000, 100000]
times = []

for size in sizes:
    arr = sorted(random.sample(range(size * 10), size))
    x = random.choice(arr)

    start_time = time.time()
    binary_search(arr, x)
    end_time = time.time()
    times.append(end_time - start_time)
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, marker='o')
plt.title('Binary Search Time Complexity')
plt.xlabel('List Size')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.show()
